# %% [markdown]
# <a href="https://colab.research.google.com/github/Asma-Ahmed-Aqil-AL-Zubaidi/Tuwaiq_Academy_week_7/blob/main/my_Task1_CBOW.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Continuous Bag of Words (CBOW) Model

# %% [markdown]
# In this exam, we will create a CBOW model using a sample Arabic traffic corpus. The corpus consists of sentences describing various traffic scenarios. The goal of the CBOW model is to predict a target word based on its surrounding context words.

# %% [markdown]
# # Importing Required Libraries

# %% [markdown]
# In this step, we import the necessary libraries to build and train the Continuous Bag of Words (CBOW) model.
#
# - **TensorFlow and Keras**: Used to build the neural network model, including the layers like `Embedding`, `Dense`, and `Lambda`.
# - **Tokenizer**: A utility from Keras for tokenizing and processing text data.
# - **NumPy**: Used for handling numerical operations, particularly for processing arrays and data manipulation.
#
# These libraries will provide the essential tools for text preprocessing and model development in the upcoming steps.
#
# Add more if needed!

# %%
import numpy as np
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, Dense, Lambda
from tensorflow.keras.optimizers import Adam
import tensorflow.keras.backend as K
import random

# %% [markdown]
# # Preparing the Corpus

# %% [markdown]
# In this step, we initialize the corpus that will be used for training the Continuous Bag of Words (CBOW) model. The corpus consists of Arabic sentences, each of which describes different traffic scenarios.
#
# - **Corpus**: A collection of traffic-related sentences in Arabic.
#
# This step sets up the text data that we will use in the upcoming stages of tokenization and model training.

# %%
corpus = [
    "الطريق مزدحم اليوم بسبب الحادث المروري الذي حدث صباحاً ويؤدي إلى تأخير كبير في الوصول",
    "كان الطريق مزدحما للغاية والسيارات متوقفة تقريباً نتيجة الازدحام الشديد والحركة بطيئة جداً ولا تتحسن",
    "أنا أحب الذهاب إلى السوق في الصباح الباكر لتفادي الازدحام وشراء الخضروات الطازجة دون الانتظار في الطريق",
    "السيارات بطيئة بسبب الازدحام المروري في الشارع الرئيسي والتأخير في حركة المرور خلال ساعات الذروة",
    "هناك ازدحام مروري في الشارع بسبب أعمال البناء والحفريات التي تعطل حركة السيارات وتتسبب في تأخير كبير",
    "ازدحام السيارات يزداد في المساء عندما يبدأ الجميع بالعودة إلى منازلهم من العمل وتتوقف حركة المرور بالكامل",
    "الطريق السريع يشهد ازدحاما مستمرا خلال فترة الظهيرة بسبب الشاحنات الكبيرة التي تبطئ حركة السير",
    "الحافلات والسيارات عالقة في الازدحام المروري في المنطقة التجارية مما يؤدي إلى تأخير وصول الناس إلى وجهاتهم",
    "حركة المرور مزدحمة اليوم بسبب الفعاليات التي تقام في وسط المدينة مما يزيد من صعوبة الوصول إلى هناك",
    "كان من الصعب جدا القيادة على الطريق الرئيسي اليوم بسبب الازدحام الخانق الذي استمر طوال اليوم",
    "الطريق إلى المطار مزدحم اليوم بسبب الحوادث المتكررة والتأخيرات الكبيرة في حركة المرور على الطريق السريع",
    "الشارع مزدحم بالسيارات والحافلات الكبيرة مما يجعل التنقل بطيئًا جدًا ويزيد من وقت الوصول إلى العمل",
    "ازدحام السيارات في المدينة أصبح مشكلة كبيرة خاصة خلال ساعات الذروة حيث يصعب التحرك بسرعة",
    "تفاقم الازدحام في الطرق الجانبية بسبب إغلاق الطريق الرئيسي المؤدي إلى وسط المدينة لصيانة الجسر",
    "ازدحام مروري خانق يواجه السكان يوميًا خلال تنقلهم من وإلى العمل على الطرق السريعة المؤدية إلى المدينة",
    "التأخيرات المرورية اليوم ناجمة عن سوء الأحوال الجوية والضباب الذي يعيق الرؤية ويبطئ حركة السيارات",
    "حوادث السير المتكررة على الطريق الزراعي تؤدي إلى ازدحام مروري شديد وتأخير كبير في وصول السيارات",
    "كانت حركة السير اليوم غير منتظمة بسبب تنظيم حدث رياضي كبير أدى إلى إغلاق بعض الشوارع الرئيسية",
    "الأعمال الإنشائية في الشارع الرئيسي تسببت في اختناق مروري كامل وتباطؤ في حركة السيارات خلال النهار",
    "تراكم السيارات عند تقاطع الطرق الرئيسية أدى إلى ازدحام شديد وزيادة كبيرة في مدة الانتظار للوصول إلى الجهة المطلوبة"
]

# %% [markdown]
# # Defining Vocabulary and Model Parameters

# %% [markdown]
# In this step, we define key parameters that will be used to configure the CBOW model.
#
# - **Vocabulary size**: We calculate the size of the vocabulary based on the number of unique words in the corpus. The `vocab_size` represents the total number of unique tokens (words) in the dataset plus one for padding.
#
# - **Embedding size**: The `embedding_size` defines the dimensionality of the word embeddings. In this case, we set the embedding size to 10, meaning each word will be represented as a 10-dimensional vector in the embedding layer.
#
# - **Window size**: The `window_size` defines how many words to the left and right of the target word are considered as context. Here, a window size of 2 means that two words before and two words after the target word will be used as context.
#
# These parameters will play an essential role in shaping the CBOW model architecture.

# %%
tokenizer = Tokenizer()
tokenizer.fit_on_texts(corpus)

# %%
vocab_size = len(tokenizer.word_index) + 1

# %%
embedding_size = 10
window_size = 2

# %%
print(f'Vocabulary Size: {vocab_size}')
# Out:
# Vocabulary Size: 179

# %% [markdown]
# # Preparing Context-Target Pairs for CBOW

# %% [markdown]
# In this step, we generate the context-target pairs from the tokenized sequences to train the CBOW model.
#
# - **Context words**: For each word in a sequence, the surrounding words (within the window size) are considered as context. The context consists of the words immediately before and after the target word.
#
# - **Target word**: The word in the middle of the context window is treated as the target word that the model will learn to predict.
#
# We iterate through each sequence, collecting the context words and corresponding target words:
# - For each word in a sequence, we gather the surrounding words based on the defined window size.
# - The middle word is the target, and the surrounding words form the context.
#
# Finally:
# - **`X`**: An array of context words.
# - **`y`**: The target words are one-hot encoded, which means they are converted into a categorical format where each word is represented as a vector of length equal to the vocabulary size.
#
# These context-target pairs will be used to train the CBOW model to predict a target word based on its context.

# %%
def generate_context_target_pairs(corpus, window_size, tokenizer):
    context_words = []
    target_words = []

    sequences = tokenizer.texts_to_sequences(corpus)

    for sequence in sequences:
        for i, target_word in enumerate(sequence):
            start = max(0, i - window_size)
            end = min(len(sequence), i + window_size + 1)
            context = [sequence[j] for j in range(start, end) if j != i]
            if len(context) == 2 * window_size:
                context_words.append(context)
                target_words.append(target_word)

    return np.array(context_words), np.array(target_words)

X, y = generate_context_target_pairs(corpus, window_size, tokenizer)


y = np.eye(vocab_size)[y]

print(f'Context Words Shape: {X.shape}, Target Words Shape: {y.shape}')
# Out:
# Context Words Shape: (244, 4), Target Words Shape: (244, 179)

# %% [markdown]
# # Building and Training the CBOW Model

# %% [markdown]
# In this step, we build and train the Continuous Bag of Words (CBOW) model using the context-target pairs created earlier.
#
# 1. **Model architecture**:
#    - **Embedding layer**: This layer transforms the input context words into dense vector representations (embeddings) of size defined by `embedding_size`. The `input_dim` is set to the vocabulary size, and the `input_length` is twice the window size (since context consists of words from both sides of the target).
#
#    - **Lambda layer**: This layer computes the mean of the context word embeddings. It averages the embeddings of the context words to generate a single representation that will be used to predict the target word.
#
#    - **Dense layer**: This fully connected layer outputs a probability distribution over the vocabulary, using the softmax activation function. It predicts the most likely target word based on the context word embeddings.
#
# 2. **Compilation**:
#    The model is compiled using the Adam optimizer and categorical cross-entropy as the loss function, which is suitable for multi-class classification tasks. Accuracy is used as a metric to evaluate the model's performance during training.
#
# 3. **Training the model**:
#    The model is trained on the context-target pairs for 500 epochs. During each epoch, the model learns to predict the target word based on the context, refining its weights to improve accuracy.
#
# 4. **Saving the model weights**:
#    After training, the model weights are saved to a file (`cbow_model.weights.h5`) for future use. This allows us to load the trained model later without retraining.
#
# By the end of this step, the CBOW model will have learned to predict target words based on their surrounding context from the given corpus.

# %%
model = Sequential()
model.add(Embedding(input_dim=vocab_size, output_dim=embedding_size, input_length=2*window_size))
model.add(Lambda(lambda x: K.mean(x, axis=1)))
model.add(Dense(vocab_size, activation='softmax'))
model.compile(optimizer=Adam(), loss='categorical_crossentropy', metrics=['accuracy'])
model.fit(X, y, epochs=500, verbose=2)
model.save_weights('cbow_model.weights.h5')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# Epoch 1/500
# 8/8 - 1s - 150ms/step - accuracy: 0.0041 - loss: 5.1872
# Epoch 2/500
# 8/8 - 0s - 4ms/step - accuracy: 0.0328 - loss: 5.1820
# Epoch 3/500
# 8/8 - 0s - 8ms/step - accuracy: 0.0615 - loss: 5.1775
# Epoch 4/500
# 8/8 - 0s - 5ms/step - accuracy: 0.0738 - loss: 5.1732
# Epoch 5/500
# 8/8 - 0s - 7ms/step - accuracy: 0.0943 - loss: 5.1687
# Epoch 6/500
# 8/8 - 0s - 4ms/step - accuracy: 0.0902 - loss: 5.1642
# Epoch 7/500
# 8/8 - 0s - 4ms/step - accuracy: 0.1025 - loss: 5.1594
# Epoch 8/500
# 8/8 - 0s - 4ms/step - accuracy: 0.1025 - loss: 5.1544
# Epoch 9/500
# 8/8 - 0s - 7ms/step - accuracy: 0.1148 - loss: 5.1494
# Epoch 10/500
# 8/8 - 0s - 4ms/step - accuracy: 0.1189 - loss: 5.1440
# Epoch 11/500
# 8/8 - 0s - 4ms/step - accuracy: 0.1189 - loss: 5.1382
# Epoch 12/500
# 8/8 - 0s - 7ms/step - accuracy: 0.1148 - loss: 5.1322
# Epoch 13/500
# 8/8 - 0s - 7ms/step - accuracy: 0.1148 - loss: 5.1258
# Epoch 14/500
# 8/8 - 0s - 7ms/step - accuracy: 0.1107 - loss: 5.1190
# Epoch 15/500
# 8/8 - 0s - 7ms/step - accuracy: 0.1189 - loss: 5.1117
# Epoch 16/500
# 8/8 - 0s - 8ms/step - accuracy: 0.5369 - loss: 1.9790
# Epoch 206/500
# 8/8 - 0s - 7ms/step - accuracy: 0.5451 - loss: 1.9690
# Epoch 207/500
# 8/8 - 0s - 8ms/step - accuracy: 0.5533 - loss: 1.9591
# Epoch 208/500
# 8/8 - 0s - 5ms/step - accuracy: 0.5656 - loss: 1.9496
# Epoch 209/500
# 8/8 - 0s - 7ms/step - accuracy: 0.5697 - loss: 1.9398
# Epoch 210/500
# 8/8 - 0s - 7ms/step - accuracy: 0.5738 - loss: 1.9303
# Epoch 211/500
# 8/8 - 0s - 4ms/step - accuracy: 0.5779 - loss: 1.9206
# Epoch 212/500
# 8/8 - 0s - 7ms/step - accuracy: 0.5820 - loss: 1.9110
# Epoch 213/500
# 8/8 - 0s - 7ms/step - accuracy: 0.5984 - loss: 1.9018
# Epoch 214/500
# 8/8 - 0s - 7ms/step - accuracy: 0.6025 - loss: 1.8921
# Epoch 215/500
# 8/8 - 0s - 7ms/step - accuracy: 0.6025 - loss: 1.8826
# Epoch 216/500
# 8/8 - 0s - 4ms/step - accuracy: 0.6066 - loss: 1.8734
# Epoch 217/500
# 8/8 - 0s - 7ms/step - accuracy: 0.6148 - loss: 1.8641
# Epoch 218/500
# 8/8 - 0s - 7ms/step - accuracy: 0.6148 - loss: 1.8548
# Epoch 219/500
# 8/8 - 0s - 7ms/step - accuracy: 0.6189 - loss: 1.8456
# Epoch 220/500
# 8/8 - 0s - 8ms/step - accuracy: 0.6270 - loss: 1.8365
# Epoch 221/500
# 8/8 - 0s - 6ms/step - accuracy: 0.6352 - loss: 1.8274
# Epoch 222/500
# 8/8 - 0s - 7ms/step - accuracy: 0.6352 - loss: 1.8183
# Epoch 223/500
# 8/8 - 0s - 5ms/step - accuracy: 0.6393 - loss: 1.8095
# Epoch 224/500
# 8/8 - 0s - 7ms/step - accuracy: 0.6434 - loss: 1.8004
# Epoch 225/500
# 8/8 - 0s - 7ms/step - accuracy: 0.6434 - loss: 1.7916
# Epoch 226/500
# 8/8 - 0s - 7ms/step - accuracy: 0.6475 - loss: 1.7829
# Epoch 227/500
# 8/8 - 0s - 7ms/step - accuracy: 0.6475 - loss: 1.7740
# Epoch 228/500
# 8/8 - 0s - 7ms/step - accuracy: 0.6434 - loss: 1.7653
# Epoch 229/500
# 8/8 - 0s - 7ms/step - accuracy: 0.6598 - loss: 1.7565
# Epoch 230/500
# 8/8 - 0s - 8ms/step - accuracy: 0.6516 - loss: 1.7481
# Epoch 231/500
# 8/8 - 0s - 7ms/step - accuracy: 0.6598 - loss: 1.7394
# Epoch 232/500
# 8/8 - 0s - 7ms/step - accuracy: 0.6598 - loss: 1.7307
# Epoch 233/500
# 8/8 - 0s - 7ms/step - accuracy: 0.6639 - loss: 1.7221
# Epoch 234/500
# 8/8 - 0s - 7ms/step - accuracy: 0.6721 - loss: 1.7139
# Epoch 235/500
# 8/8 - 0s - 7ms/step - accuracy: 0.6721 - loss: 1.7054
# Epoch 236/500
# Epoch 331/500
# 8/8 - 0s - 7ms/step - accuracy: 0.8648 - loss: 1.0705
# Epoch 332/500
# 8/8 - 0s - 5ms/step - accuracy: 0.8648 - loss: 1.0653
# Epoch 333/500
# 8/8 - 0s - 7ms/step - accuracy: 0.8648 - loss: 1.0601
# Epoch 334/500
# 8/8 - 0s - 7ms/step - accuracy: 0.8689 - loss: 1.0551
# Epoch 335/500
# 8/8 - 0s - 7ms/step - accuracy: 0.8689 - loss: 1.0497
# Epoch 336/500
# 8/8 - 0s - 7ms/step - accuracy: 0.8730 - loss: 1.0446
# Epoch 337/500
# 8/8 - 0s - 7ms/step - accuracy: 0.8730 - loss: 1.0398
# Epoch 338/500
# 8/8 - 0s - 7ms/step - accuracy: 0.8811 - loss: 1.0346
# Epoch 339/500
# 8/8 - 0s - 7ms/step - accuracy: 0.8811 - loss: 1.0298
# Epoch 340/500
# 8/8 - 0s - 5ms/step - accuracy: 0.8811 - loss: 1.0249
# Epoch 341/500
# 8/8 - 0s - 7ms/step - accuracy: 0.8811 - loss: 1.0197
# Epoch 342/500
# 8/8 - 0s - 7ms/step - accuracy: 0.8811 - loss: 1.0147
# Epoch 343/500
# 8/8 - 0s - 7ms/step - accuracy: 0.8811 - loss: 1.0098
# Epoch 344/500
# 8/8 - 0s - 7ms/step - accuracy: 0.8893 - loss: 1.0051
# Epoch 345/500
# 8/8 - 0s - 4ms/step - accuracy: 0.8893 - loss: 1.0001
# Epoch 346/500
# 8/8 - 0s - 7ms/step - accuracy: 0.8934 - loss: 0.9952
# Epoch 347/500
# 8/8 - 0s - 7ms/step - accuracy: 0.8934 - loss: 0.9904
# Epoch 348/500
# 8/8 - 0s - 5ms/step - accuracy: 0.9016 - loss: 0.9856
# Epoch 349/500
# 8/8 - 0s - 7ms/step - accuracy: 0.9016 - loss: 0.9808
# Epoch 350/500
# 8/8 - 0s - 7ms/step - accuracy: 0.9016 - loss: 0.9760
# Epoch 351/500
# 8/8 - 0s - 4ms/step - accuracy: 0.9016 - loss: 0.9712
# Epoch 352/500
# 8/8 - 0s - 7ms/step - accuracy: 0.9057 - loss: 0.9665
# Epoch 353/500
# 8/8 - 0s - 7ms/step - accuracy: 0.9057 - loss: 0.9619
# Epoch 354/500
# 8/8 - 0s - 7ms/step - accuracy: 0.9016 - loss: 0.9571
# Epoch 355/500
# 8/8 - 0s - 4ms/step - accuracy: 0.9057 - loss: 0.9525
# Epoch 356/500
# 8/8 - 0s - 4ms/step - accuracy: 0.9098 - loss: 0.9478
# Epoch 357/500
# 8/8 - 0s - 7ms/step - accuracy: 0.9098 - loss: 0.9433
# Epoch 358/500
# 8/8 - 0s - 8ms/step - accuracy: 0.9139 - loss: 0.9387
# Epoch 359/500
# 8/8 - 0s - 7ms/step - accuracy: 0.9139 - loss: 0.9341
# Epoch 360/500
# 8/8 - 0s - 8ms/step - accuracy: 0.9139 - loss: 0.9296
# Epoch 361/500
# 8/8 - 0s - 17ms/step - accuracy: 0.9139 - loss: 0.9252
# Epoch 362/500
# Epoch 394/500
# 8/8 - 0s - 6ms/step - accuracy: 0.9549 - loss: 0.7862
# Epoch 395/500
# 8/8 - 0s - 7ms/step - accuracy: 0.9549 - loss: 0.7825
# Epoch 396/500
# 8/8 - 0s - 7ms/step - accuracy: 0.9549 - loss: 0.7785
# Epoch 397/500
# 8/8 - 0s - 8ms/step - accuracy: 0.9549 - loss: 0.7747
# Epoch 398/500
# 8/8 - 0s - 16ms/step - accuracy: 0.9549 - loss: 0.7707
# Epoch 399/500
# 8/8 - 0s - 8ms/step - accuracy: 0.9672 - loss: 0.7668
# Epoch 400/500
# 8/8 - 0s - 7ms/step - accuracy: 0.9672 - loss: 0.7634
# Epoch 401/500
# 8/8 - 0s - 7ms/step - accuracy: 0.9713 - loss: 0.7595
# Epoch 402/500
# 8/8 - 0s - 8ms/step - accuracy: 0.9713 - loss: 0.7557
# Epoch 403/500
# 8/8 - 0s - 7ms/step - accuracy: 0.9713 - loss: 0.7518
# Epoch 404/500
# 8/8 - 0s - 8ms/step - accuracy: 0.9754 - loss: 0.7481
# Epoch 405/500
# 8/8 - 0s - 7ms/step - accuracy: 0.9754 - loss: 0.7444
# Epoch 406/500
# 8/8 - 0s - 8ms/step - accuracy: 0.9754 - loss: 0.7408
# Epoch 407/500
# 8/8 - 0s - 4ms/step - accuracy: 0.9754 - loss: 0.7371
# Epoch 408/500
# 8/8 - 0s - 7ms/step - accuracy: 0.9754 - loss: 0.7333
# Epoch 409/500
# 8/8 - 0s - 7ms/step - accuracy: 0.9754 - loss: 0.7296
# Epoch 410/500
# 8/8 - 0s - 7ms/step - accuracy: 0.9754 - loss: 0.7262
# Epoch 411/500
# 8/8 - 0s - 8ms/step - accuracy: 0.9754 - loss: 0.7226
# Epoch 412/500
# 8/8 - 0s - 7ms/step - accuracy: 0.9754 - loss: 0.7189
# Epoch 413/500
# 8/8 - 0s - 7ms/step - accuracy: 0.9754 - loss: 0.7154
# Epoch 414/500
# 8/8 - 0s - 7ms/step - accuracy: 0.9754 - loss: 0.7118
# Epoch 415/500
# 8/8 - 0s - 5ms/step - accuracy: 0.9754 - loss: 0.7081
# Epoch 416/500
# 8/8 - 0s - 7ms/step - accuracy: 0.9795 - loss: 0.7048
# Epoch 417/500
# 8/8 - 0s - 5ms/step - accuracy: 0.9795 - loss: 0.7011
# Epoch 418/500
# 8/8 - 0s - 7ms/step - accuracy: 0.9795 - loss: 0.6977
# Epoch 419/500
# 8/8 - 0s - 5ms/step - accuracy: 0.9795 - loss: 0.6942
# Epoch 420/500
# 8/8 - 0s - 5ms/step - accuracy: 0.9795 - loss: 0.6908
# Epoch 421/500
# 8/8 - 0s - 7ms/step - accuracy: 0.9795 - loss: 0.6873
# Epoch 422/500
# 8/8 - 0s - 7ms/step - accuracy: 0.9795 - loss: 0.6839
# Epoch 423/500
# 8/8 - 0s - 8ms/step - accuracy: 0.9795 - loss: 0.6804
# Epoch 424/500
# 8/8 - 0s - 8ms/step - accuracy: 0.9795 - loss: 0.6771
# Epoch 425/500
# Epoch 457/500
# 8/8 - 0s - 7ms/step - accuracy: 0.9877 - loss: 0.5734
# Epoch 458/500
# 8/8 - 0s - 4ms/step - accuracy: 0.9877 - loss: 0.5707
# Epoch 459/500
# 8/8 - 0s - 7ms/step - accuracy: 0.9877 - loss: 0.5678
# Epoch 460/500
# 8/8 - 0s - 8ms/step - accuracy: 0.9877 - loss: 0.5649
# Epoch 461/500
# 8/8 - 0s - 7ms/step - accuracy: 0.9877 - loss: 0.5620
# Epoch 462/500
# 8/8 - 0s - 7ms/step - accuracy: 0.9877 - loss: 0.5592
# Epoch 463/500
# 8/8 - 0s - 7ms/step - accuracy: 0.9877 - loss: 0.5562
# Epoch 464/500
# 8/8 - 0s - 7ms/step - accuracy: 0.9877 - loss: 0.5533
# Epoch 465/500
# 8/8 - 0s - 7ms/step - accuracy: 0.9877 - loss: 0.5506
# Epoch 466/500
# 8/8 - 0s - 7ms/step - accuracy: 0.9877 - loss: 0.5479
# Epoch 467/500
# 8/8 - 0s - 7ms/step - accuracy: 0.9877 - loss: 0.5452
# Epoch 468/500
# 8/8 - 0s - 7ms/step - accuracy: 0.9877 - loss: 0.5423
# Epoch 469/500
# 8/8 - 0s - 5ms/step - accuracy: 0.9877 - loss: 0.5396
# Epoch 470/500
# 8/8 - 0s - 5ms/step - accuracy: 0.9877 - loss: 0.5369
# Epoch 471/500
# 8/8 - 0s - 5ms/step - accuracy: 0.9877 - loss: 0.5342
# Epoch 472/500
# 8/8 - 0s - 7ms/step - accuracy: 0.9877 - loss: 0.5315
# Epoch 473/500
# 8/8 - 0s - 8ms/step - accuracy: 0.9877 - loss: 0.5288
# Epoch 474/500
# 8/8 - 0s - 5ms/step - accuracy: 0.9877 - loss: 0.5261
# Epoch 475/500
# 8/8 - 0s - 4ms/step - accuracy: 0.9877 - loss: 0.5234
# Epoch 476/500
# 8/8 - 0s - 7ms/step - accuracy: 0.9877 - loss: 0.5208
# Epoch 477/500
# 8/8 - 0s - 7ms/step - accuracy: 0.9877 - loss: 0.5181
# Epoch 478/500
# 8/8 - 0s - 4ms/step - accuracy: 0.9877 - loss: 0.5154
# Epoch 479/500
# 8/8 - 0s - 7ms/step - accuracy: 0.9877 - loss: 0.5129
# Epoch 480/500
# 8/8 - 0s - 7ms/step - accuracy: 0.9877 - loss: 0.5102
# Epoch 481/500
# 8/8 - 0s - 5ms/step - accuracy: 0.9877 - loss: 0.5077
# Epoch 482/500
# 8/8 - 0s - 4ms/step - accuracy: 0.9877 - loss: 0.5051
# Epoch 483/500
# 8/8 - 0s - 7ms/step - accuracy: 0.9877 - loss: 0.5026
# Epoch 484/500
# 8/8 - 0s - 7ms/step - accuracy: 0.9877 - loss: 0.5000
# Epoch 485/500
# 8/8 - 0s - 8ms/step - accuracy: 0.9877 - loss: 0.4975
# Epoch 486/500
# 8/8 - 0s - 5ms/step - accuracy: 0.9877 - loss: 0.4949
# Epoch 487/500
# 8/8 - 0s - 6ms/step - accuracy: 0.9877 - loss: 0.4923
# Epoch 488/500
# 8/8 - 0s - 5ms/step - accuracy: 0.9877 - loss: 0.4899
# Epoch 489/500
# 8/8 - 0s - 6ms/step - accuracy: 0.9918 - loss: 0.4874
# Epoch 490/500
# 8/8 - 0s - 7ms/step - accuracy: 0.9918 - loss: 0.4849
# Epoch 491/500
# 8/8 - 0s - 7ms/step - accuracy: 0.9918 - loss: 0.4825
# Epoch 492/500
# 8/8 - 0s - 5ms/step - accuracy: 0.9918 - loss: 0.4799
# Epoch 493/500
# 8/8 - 0s - 7ms/step - accuracy: 0.9918 - loss: 0.4775
# Epoch 494/500
# 8/8 - 0s - 7ms/step - accuracy: 0.9918 - loss: 0.4751
# Epoch 495/500
# 8/8 - 0s - 8ms/step - accuracy: 0.9918 - loss: 0.4727
# Epoch 496/500
# 8/8 - 0s - 7ms/step - accuracy: 0.9918 - loss: 0.4703
# Epoch 497/500
# 8/8 - 0s - 7ms/step - accuracy: 0.9918 - loss: 0.4680
# Epoch 498/500
# 8/8 - 0s - 4ms/step - accuracy: 0.9918 - loss: 0.4655
# Epoch 499/500
# 8/8 - 0s - 7ms/step - accuracy: 0.9918 - loss: 0.4632
# Epoch 500/500
# 8/8 - 0s - 7ms/step - accuracy: 0.9918 - loss: 0.4608

# %% [markdown]
# The first good observation is that by increasing the number of training laps (Epoch), the accuracy increases, so I will try, if strength allows, to increase the number of (Epoch).
#
#
# The accuracy is excellent and the number (Epoch) was raised to

# %% [markdown]
# # Predicting a Word Using the Trained CBOW Model

# %% [markdown]
# In this step, we define a function to predict a word based on a given context using the trained CBOW model.
#
# 1. **Function: `predict_word`**:
#    - **Input**: The function takes a list of context words as input. The number of context words should match the expected size (2 times the window size).
#    - **Context sequence conversion**: The input context words are tokenized into a sequence of integers using the same tokenizer that was used during training.
#    - **Input validation**: The function checks whether the length of the context sequence matches the expected size (2 times the window size). If not, it prints an error message.
#    - **Prediction**: The tokenized context is fed into the trained CBOW model, which predicts the probability distribution over the vocabulary.
#    - **Retrieve predicted word**: The predicted word is the one with the highest probability. The function retrieves the word corresponding to the predicted index from the tokenizer's word index.
#
# 2. **Example**:
#    - We provide a sample context: `['الحادث', 'بسبب', 'مزدحم', 'الطريق']`.
#    - The function predicts the word that fits best in this context, based on the model's learned weights.
#    - The predicted word is printed along with the input context.
#
# This function allows us to test the CBOW model by predicting words based on their surrounding context from the corpus.

# %%
def predict_word(context, tokenizer, model, window_size):
    context_sequence = tokenizer.texts_to_sequences([context])[0]

    if len(context_sequence) != 2 * window_size:
        print(f"Error: Context should be of length {2 * window_size}")
        return

    prediction = model.predict(np.array([context_sequence]))
    predicted_index = np.argmax(prediction)
    predicted_word = tokenizer.index_word[predicted_index]

    print(f'Context: {context}, Predicted Word: {predicted_word}')


predict_word(['الطريق', 'مزدحم', 'بسبب', 'الحادث'], tokenizer, model, window_size)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Context: ['الطريق', 'مزدحم', 'بسبب', 'الحادث'], Predicted Word: اليوم

# %% [markdown]
# ### At the end of this mission, I was not asked to give or write details, but I am very happy if there is any question that I can answer, thank you.**bold text**. :)
